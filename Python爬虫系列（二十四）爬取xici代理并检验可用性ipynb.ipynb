# %%
import requests
from lxml import etree
import time

# %%
url='http://www.xicidaili.com/wt/{}'.format(1)
header={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}

# %%
res=requests.get(url,headers=header)
html=etree.HTML(res.text)

# %%
tr_list=html.xpath('//div[@id="body"]/table[@id="ip_list"]/tr')
ip_list=tr_list[0].xpath("//td[2]/text()")
print(ip_list,len(ip_list))
# Out:
# ['27.44.162.242', '39.69.15.245', '117.68.193.87', '101.68.73.54', '171.217.2.95', '121.35.243.157', '27.46.41.141', '27.219.37.185', '61.155.164.107', '61.135.217.7', '118.178.124.33', '180.168.179.193', '182.88.129.43', '58.255.45.228', '211.103.208.244', '182.34.48.145', '111.155.116.200', '101.87.85.184', '61.155.164.110', '110.73.3.149', '111.155.116.215', '120.32.208.204', '111.155.116.208', '117.78.37.198', '116.6.228.51', '175.164.30.185', '218.18.232.29', '61.155.164.108', '180.173.152.82', '123.115.161.205', '111.79.198.145', '121.13.54.4', '118.75.160.115', '221.204.11.8', '110.73.169.22', '59.78.37.159', '182.37.50.96', '171.37.194.178', '110.72.39.148', '113.123.48.73', '183.186.118.41', '218.73.137.104', '222.186.45.60', '115.200.37.179', '120.25.164.134', '114.115.134.115', '220.166.241.145', '59.40.50.224', '49.68.126.158', '58.52.184.48', '110.73.13.2', '59.40.51.48', '113.223.102.144', '124.93.84.175', '182.88.242.201', '110.73.10.166', '144.123.71.222', '110.73.52.237', '59.63.74.72', '59.40.50.36', '59.40.51.9', '125.92.32.83', '116.19.98.144', '175.13.122.243', '182.88.164.154', '223.241.78.11', '59.50.68.34', '121.42.8.181', '125.46.0.62', '110.72.206.125', '182.107.79.51', '171.39.73.23', '182.96.194.88', '111.155.116.247', '119.116.182.203', '115.203.215.83', '183.12.27.188', '118.119.168.172', '111.155.116.196', '183.172.130.174', '59.40.51.99', '58.52.152.214', '124.152.185.213', '120.32.79.234', '111.155.124.73', '223.215.148.211', '114.239.145.52', '122.228.179.178', '115.219.249.75', '27.159.126.74', '223.221.61.246', '60.184.206.215', '117.65.44.62', '183.157.180.128', '223.221.58.125', '110.73.0.87', '111.155.116.238', '112.91.218.21', '180.105.146.136', '124.152.185.92'] 100

# %%
#另一中方法
import requests,re,pandas

# %%
header={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}
url='http://www.xicidaili.com/wt/'

# %%
html=requests.request('GET',url,headers=header)
html.encoding='utf-8'

# %%
html.text
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n  <title>HTTP免费HTTP代理IP__第1页HTTP</title>\n  <meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>\n  <meta name="Description" content="HTTP免费HTTP代理" />\n  <meta name="Keywords" content="HTTP,免费高匿代理,免费匿名代理,隐藏IP" />\n  <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0">\n  \u3000\u3000<meta name="applicable-device"content="pc,mobile">\n  <link rel="stylesheet" media="screen" href="http://fs.xicidaili.com/assets/application-9cf10a41b67e112fe8dd709caf886c0556b7939174952800b56a22c7591c7d40.css" />\n  <meta name="csrf-param" content="authenticity_token" />\n<meta name="csrf-token" content="+MgRSCx62j4AkS7LLiAi9jzAGlOuajhFnsJ5A4E98iX9GOQIcVX+oWiuPkWq+JoIUKjKSXtLpEkWYTnB8aMyyg==" />\n</head>\n<body>\n  <div id="wrapper">\n    <div id="header">\n      <h1>HTTP代理IP</h1>\n      <img alt="免费http代理" id="logo" src="http://fs.xicidaili.com/images/logo.png" />\n      <div id="myurl">\n        XiciDaili.com\n      </div>\n      <ul id="nav">\n        <li><a class="false" href="/">首页</a></li>\n        <li><a href="/api">API提取</a></li>\n        <li><a class="false" href="/nn/">国内高匿代理</a></li>\n        <li><a class="false" href="/nt/">国内普通代理</a></li>\n        <li><a class="false" href="/wn/">国内HTTPS代理</a></li>\n        <li><a class="active" href="/wt/">国内HTTP代理</a></li>\n        <li><a class="false" href="/articles/">代理小百科</a></li>\n      </ul>\n    </div>\n    <div id="body" class="clearfix proxies">\n      \n\n\n<div id="bread">\n  当前位置: \n  <a href="/">首页</a>\n   &gt; HTTP代理 \n</div>\n\n\n<a target="_blank" class="sideimg" href="http://www.daxiangdaili.com/"><img src="http://fs.xicidaili.com/images/side2.png" alt="Side2" /></a>\n\n  <table id="ip_list">\n    <tr>\n      <th class="country">国家</th>\n      <th>IP地址</th>\n      <th>端口</th>\n      <th>服务器地址</th>\n      <th class="country">是否匿名</th>\n      <th>类型</th>\n      <th class="country">速度</th>\n      <th class="country">连接时间</th>\n      <th width="8%">存活时间</th>\n      \n      <th width="20%">验证时间</th>\n    </tr>\n  \n    <tr class="odd">\n      <td class="country"><img src="http://fs.xicidaili.com/images/flag/cn.png" alt="Cn" /></td>\n      <td>14.211.35.140</td>\n      <td>9999</td>\n      <td>\n        <a href="/2017-11-02/guangdong">广东佛山</a>\n      </td>\n      <td class="country">透明</td>\n      <td>HTTP</td>\n      <td class="country">\n        <div title="0.216秒" class="bar">\n          <div class="bar_inner fast" style="width:89%">\n            \n          </div>\n        </div>\n      </td>\n      <td class="country">\n        <div title="0.043秒" class="bar">\n          <div class="bar_inner fast" style="width:99%">\n            \n          </div>\n        </div>\n      </td>\n      \n      <td>1天</td>\n      <td>17-11-03 21:11</td>\n    </tr>\n  \n    <tr class="">\n      <td class="country"><img src="http://fs.xicidaili.com/images/flag/cn.png" alt="Cn" /></td>\n      <td>121.40.225.209</td>\n      <td>3128</td>\n      <td>\n        <a href="/2017-11-03/hubei">湖北</a>\n      </td>\n      <td class="country">透明</td>\n      <td>HTTP</td>\n      <td class="country">\n        <div title="1.136秒" class="bar">\n          <div class="bar_inner fast" style="width:90%">\n            \n          </div>\n        </div>\n      </td>\n      <td class="country">\n        <div title="0.227秒" class="bar">\n          <div class="bar_inner fast" style="width:98%">\n            \n          </div>\n        </div>\n      </td>\n      \n      <td>40分钟</td>\n      <td>17-11-03 21:11</td>\n    </tr>\n  \n    <tr class="odd">\n      <td class="country"><img src="http://fs.xicidaili.com/images/flag/cn.png" alt="Cn" /></td>\n      <td>113.200.214.164</td>\n      <td>9999</td>\n      <td>\n        <a href="/2017-05-28/sanxi">陕西西安</a>\n      </td>\n      <td class="country">透明</td>\n      <td>HTTP</td>\n      <td class="country">\n        <div title="0.159秒" class="bar">\n          <div class="bar_inner fast" ...

# %%
#状态码
html.status_code
# Out:
# 200

# %%
ren=re.compile('<td>(.*?)</td>.*?<td>(.*?)</td>.*?<td>.*?<a href=".*?">(.*?)</a>.*?</td>.*?<td class=".*?">.*?</td>.*?<td>(.*?)</td>.*?<td>(.*?)</td>.*?<td>(.*?)</td>.*?</tr>',re.S)

# %%
data1=re.findall(ren,html.text)
data1
# Out:
# [('111.155.116.225', '8123', '北京', 'HTTP', '459天', '17-11-09 23:45'),
#  ('110.73.8.218', '8123', '广西防城港', 'HTTP', '267天', '17-11-09 23:44'),
#  ('120.32.208.204', '8118', '福建厦门', 'HTTP', '18小时', '17-11-09 23:43'),
#  ('101.87.85.184', '8118', '上海', 'HTTP', '2天', '17-11-09 23:42'),
#  ('182.34.48.145', '808', '山东烟台', 'HTTP', '3小时', '17-11-09 23:42'),
#  ('211.103.208.244', '80', '北京', 'HTTP', '18天', '17-11-09 23:42'),
#  ('58.255.45.228', '9000', '广东东莞', 'HTTP', '1小时', '17-11-09 23:42'),
#  ('180.168.179.193', '8080', '上海', 'HTTP', '106天', '17-11-09 23:42'),
#  ('118.178.124.33', '3128', '江苏苏州', 'HTTP', '506天', '17-11-09 23:41'),
#  ('61.135.217.7', '80', '北京', 'HTTP', '545天', '17-11-09 23:41'),
#  ('27.46.41.141', '9797', '广东深圳', 'HTTP', '41分钟', '17-11-09 23:41'),
#  ('59.78.37.159', '1080', '上海', 'HTTP', '5小时', '17-11-09 23:40'),
#  ('124.93.84.175', '80', '辽宁大连', 'HTTP', '2小时', '17-11-09 23:39'),
#  ('113.123.48.73', '808', '山东威海', 'HTTP', '5小时', '17-11-09 23:36'),
#  ('221.204.11.8', '8080', '山西太原', 'HTTP', '365天', '17-11-09 23:35'),
#  ('27.44.162.242', '9999', '广东东莞', 'HTTP', '3分钟', '17-11-09 23:33'),
#  ('39.69.15.245', '53281', '山东', 'HTTP', '11天', '17-11-09 23:33'),
#  ('117.68.193.87', '808', '安徽合肥市巢湖', 'HTTP', '4小时', '17-11-09 23:33'),
#  ('101.68.73.54', '53281', '浙江杭州', 'HTTP', '85天', '17-11-09 23:32'),
#  ('171.217.2.95', '8118', '四川成都', 'HTTP', '4小时', '17-11-09 23:32'),
#  ('121.35.243.157', '8080', '广东深圳', 'HTTP', '276天', '17-11-09 23:32'),
#  ('27.219.37.185', '8118', '山东', 'HTTP', '1天', '17-11-09 23:31'),
#  ('182.88.129.43', '8123', '广西南宁', 'HTTP', '566天', '17-11-09 23:31'),
#  ('111.155.116.200', '8123', '北京', 'HTTP', '450天', '17-11-09 23:30'),
#  ('61.155.164.110', '3128', '江苏苏州', 'HTTP', '503天', '17-11-09 23:30'),
#  ('110.73.3.149', '8123', '广西防城港', 'HTTP', '108天', '17-11-09 23:22'),
#  ('111.155.116.215', '8123', '北京', 'HTTP', '212天', '17-11-09 23:22'),
#  ('111.155.116.208', '8123', '北京', 'HTTP', '459天', '17-11-09 23:20'),
#  ('117.78.37.198', '8000', '辽宁鞍山', 'HTTP', '101天', '17-11-09 23:20'),
#  ('116.6.228.51', '808', '广东东莞', 'HTTP', '1天', '17-11-09 23:20'),
#  ('175.164.30.185', '80', '辽宁', 'HTTP', '1天', '17-11-09 23:16'),
#  ('218.18.232.29', '8080', '广东深圳', 'HTTP', '161天', '17-11-09 23:13'),
#  ('61.155.164.108', '3128', '江苏苏州', 'HTTP', '504天', '17-11-09 23:11'),
#  ('180.173.152.82', '53281', '上海', 'HTTP', '23天', '17-11-09 23:11'),
#  ('123.115.161.205', '9000', '北京', 'HTTP', '22小时', '17-11-09 23:11'),
#  ('111.79.198.145', '53281', '江西赣州', 'HTTP', '1天', '17-11-09 23:10'),
#  ('121.13.54.4', '8118', '广东东莞', 'HTTP', '28天', '17-11-09 23:07'),
#  ('118.75.160.115', '8118', '山西长治', 'HTTP', '13小时', '17-11-09 23:03'),
#  ('110.73.169.22', '8123', '广西柳州', 'HTTP', '1分钟', '17-11-09 23:00'),
#  ('182.37.50.96', '808', '山东日照', 'HTTP', '1分钟', '17-11-09 23:00'),
#  ('171.37.194.178', '8123', '广西', 'HTTP', '423天', '17-11-09 23:00'),
#  ('110.72.39.148', '8123', '广西贵港', 'HTTP', '1分钟', '17-11-09 23:00'),
#  ('183.186.118.41', '80', '山西吕梁', 'HTTP', '1天', '17-11-09 22:58'),
#  ('218.73.137.104', '26119', '浙江温州', 'HTTP', '225天', '17-11-09 22:55'),
#  ('222.186.45.60', '62222', '江苏镇江', 'HTTP', '253天', '17-11-09 22:51'),
#  ('115.200.37.179', '80', '浙江杭州', 'HTTP', '14小时', '17-11-09 22:44'),
#  ('120.25.164.134', '8118', '北京', 'HTTP', '13天', '17-11-09 22:39'),
#  ('114.115.134.115', '80', '四川成都', 'HTTP', '5小时', '17-11-09 22:33'),
#  ('59.40.50.224', '8010', '广东深圳市罗湖区', 'HTTP', '12天', '17-11-09 22:33'),
#  ('49.68.126.158', '808', '江苏苏州', 'HTTP', '3小时', '17-11-09 22:31'),
#  ('58.52.184.48', '808', '湖北咸宁', 'HTTP', '3小时', '17-11-09 22:16'),
#  ('110.73.13.2', '8123', '广西防城港', 'HTTP', '178天', '17-11-09 22:15'),
#  ('59.40.51.48', '8010', '广东深圳市罗湖区', 'HTTP', '31天', '17-11-09 22:15'),
#  ('113.223.102.144', '8118', '湖南', 'HTTP', '4小时', '17-11-09 22:13'),
#  ('182.88.242.201', '9797', '广西南宁', 'HTTP', '1分钟', '17-11-09 22:00'),
#  ('110.73.10.166', '8123', '广西防城港', 'HTTP', '544天', '17-11-09 21:32'),
#  ('144.123.71.222', '28632', '山东', 'HTTP', '1分钟', '17-11-09 21:15'),
#  ('110.73.52.237', '8123', '广西南宁', 'HTTP', '1分钟', '17-11-09 21:15'),
#  ('59.63.74.72', '4362', '江西景德镇', 'HTTP', '13小时', '17-11-09 20:45'),
#  ('59.40.50.36', '8010', '广东深圳市罗湖区', 'HTTP', '3分钟', '17-11-09 20:33'),
#  ('59.40.51.9', '8010', '广东深圳市罗湖区', 'HTTP', '1分钟', '17-11-09 20:15'),
#  ('125.92.32.83', '3128', '广东江门', 'HTTP', '1分钟', '17-11-09 20:00'),
#  ('116.19.98.144', '9797', '广东珠海', 'HTTP', '4小时', '17-11-09 19:55'),
#  ('175.13.122.243', '53281', '湖南', 'HTTP', '1天', '17-11-09 19:33'),
#  ('182.88.164.154', '8123', '广西南宁', 'HTTP', '1分钟', '17-11-09 19:30'),
#  ('223.241.78.11', '8010', '安徽芜湖', 'HTTP', '1分钟', '17-11-09 19:15'),
#  ('59.50.68.34', '53281', '海南海口', 'HTTP', '106天', '17-11-09 19:07'),
#  ('121.42.8.181', '808', '河北石家庄', 'HTTP', '15天', '17-11-09 18:37'),
#  ('125.46.0.62', '53281', '河南济源', 'HTTP', '85天', '17-11-09 18:29'),
#  ('110.72.206.125', '80', '广西柳州', 'HTTP', '1分钟', '17-11-09 18:16'),
#  ('182.107.79.51', '4397', '江西', 'HTTP', '59分钟', '17-11-09 18:00'),
#  ('171.39.73.23', '8123', '广西百色', 'HTTP', '1分钟', '17-11-09 17:45'),
#  ('182.96.194.88', '8118', '江西南昌', 'HTTP', '6天', '17-11-09 17:42'),
#  ('111.155.116.247', '8123', '北京', 'HTTP', '466天', '17-11-09 17:31'),
#  ('119.116.182.203', '80', '辽宁本溪', 'HTTP', '8小时', '17-11-09 17:21'),
#  ('115.203.215.83', '38752', '浙江台州', 'HTTP', '1分钟', '17-11-09 17:15'),
#  ('183.12.27.188', '8118', '广东深圳', 'HTTP', '18小时', '17-11-09 17:14'),
#  ('118.119.168.172', '9999', '四川乐山', 'HTTP', '447天', '17-11-09 17:12'),
#  ('111.155.116.196', '8123', '北京', 'HTTP', '458天', '17-11-09 17:11'),
#  ('183.172.130.174', '8118', '北京', 'HTTP', '1分钟', '17-11-09 17:01'),
#  ('59.40.51.99', '8010', '广东深圳市罗湖区', 'HTTP', '20天', '17-11-09 16:51'),
#  ('58.52.152.214', '808', '湖北咸宁', 'HTTP', '1分钟', '17-11-09 16:45'),
#  ('124.152.185.213', '4329', '甘肃', 'HTTP', '1天', '17-11-09 16:44'),
#  ('120.32.79.234', '8118', '福建福州', 'HTTP', '1小时', '17-11-09 16:39'),
#  ('111.155.124.73', '8123', '北京', 'HTTP', '471天', '17-11-09 16:22'),
#  ('223.215.148.211', '52319', '安徽', 'HTTP', '1分钟', '17-11-09 16:16'),
#  ('114.239.145.52', '808', '江苏宿迁市泗阳县', 'HTTP', '144天', '17-11-09 16:11'),
#  ('122.228.179.178', '80', '浙江温州', 'HTTP', '438天', '17-11-09 15:53'),
#  ('115.219.249.75', '9999', '浙江温州', 'HTTP', '1分钟', '17-11-09 15:31'),
#  ('27.159.126.74', '8118', '福建莆田', 'HTTP', '259天', '17-11-09 15:26'),
#  ('223.221.61.246', '4310', '青海', 'HTTP', '8小时', '17-11-09 15:18'),
#  ('60.184.206.215', '4378', '浙江丽水', 'HTTP', '15分钟', '17-11-09 15:15'),
#  ('117.65.44.62', '52136', '安徽蚌埠', 'HTTP', '6小时', '17-11-09 15:14'),
#  ('183.157.180.128', '80', '浙江杭州', 'HTTP', '1分钟', '17-11-09 15:00'),
#  ('223.221.58.125', '4310', '青海', 'HTTP', '1天', '17-11-09 14:55'),
#  ('110.73.0.87', '8123', '广西防城港', 'HTTP', '358天', '17-11-09 14:51'),
#  ('111.155.116.238', '8123', '北京', 'HTTP', '235天', '17-11-09 14:46'),
#  ('112.91.218.21', '9000', '广东河源', 'HTTP', '577天', '17-11-09 14:44')]

# %%
data2=pandas.DataFrame(data1)
data2
# Out:
#                   0      1         2     3     4               5
# 0     14.211.35.140   9999      广东佛山  HTTP    1天  17-11-03 21:11
# 1    121.40.225.209   3128        湖北  HTTP  40分钟  17-11-03 21:11
# 2   113.200.214.164   9999      陕西西安  HTTP  159天  17-11-03 21:09
# 3    120.25.164.134   8118        北京  HTTP    7天  17-11-03 21:07
# 4    121.14.170.230   3128      广东中山  HTTP   15天  17-11-03 21:05
# 5      58.87.74.207     80      浙江温州  HTTP   4小时  17-11-03 21:03
# 6      112.95.21.56   8888      广东深圳  HTTP   27天  17-11-03 21:03
# 7      61.135.217.7     80        北京  HTTP  539天  17-11-03 21:02
# 8    118.178.124.33   3128        上海  HTTP  100天  17-11-03 21:02
# 9    61.155.164.110   3128      江苏苏州  HTTP  497天  17-11-03 21:01
# 10   61.155.164.111   3128      江苏苏州  HTTP  497天  17-11-03 21:01
# 11    218.83.49.233   8118        上海  HTTP   1分钟  17-11-03 21:01
# 12   61.155.164.108   3128      江苏苏州  HTTP  498天  17-11-03 21:00
# 13   110.72.204.137     80      广西柳州  HTTP   1分钟  17-11-03 21:00
# 14    61.135.155.82    443        北京  HTTP  113天  17-11-03 21:00
# 15    222.82.248.74  53281    新疆乌鲁木齐  HTTP   77天  17-11-03 20:57
# 16    119.29.158.87     80        北京  HTTP    1天  17-11-03 20:56
# 17    121.13.55.212   8118      广东东莞  HTTP  54分钟  17-11-03 20:56
# 18   183.163.45.197  52225      安徽蚌埠  HTTP   9分钟  17-11-03 20:55
# 19     121.31.103.4   8123     广西防城港  HTTP  537天  17-11-03 20:55
# 20   61.155.164.107   3128      江苏苏州  HTTP  499天  17-11-03 20:52
# 21    117.78.37.198   8000      辽宁鞍山  HTTP   95天  17-11-03 20:51
# 22     59.38.62.169   9797      广东珠海  HTTP   5小时  17-11-03 20:45
# 23    118.187.58.34  53281        北京  HTTP   74天  17-11-03 20:42
# 24     36.48.28.219   8118        吉林  HTTP   3小时  17-11-03 20:41
# 25      27.22.49.46    808      湖北襄阳  HTTP   6小时  17-11-03 20:37
# 26    121.228.77.83   8118      江苏苏州  HTTP  10小时  17-11-03 20:30
# 27   218.106.98.166  53281      江苏扬州  HTTP   76天  17-11-03 20:22
# 28    121.13.54.217   8118      广东东莞  HTTP  35分钟  17-11-03 20:21
# 29      49.64.68.36   3128      江苏苏州  HTTP   1小时  17-11-03 20:18
# ..              ...    ...       ...   ...   ...             ...
# 68    115.56.135.27   9000      河南焦作  HTTP   14天  17-11-03 15:31
# 69  223.241.119.129    808        安徽  HTTP   92天  17-11-03 15:22
# 70   162.105.86.202   8118        北京  HTTP    6天  17-11-03 15:19
# 71  139.224.238.223   8888        云南  HTTP  18小时  17-11-03 14:44
# 72     175.7.224.24    808        湖南  HTTP   1小时  17-11-03 14:03
# 73   115.46.149.144   8123      广西钦州  HTTP   1小时  17-11-03 13:47
# 74   119.39.114.166    808      湖南长沙  HTTP   3小时  17-11-03 13:35
# 75    222.186.45.57  62386      江苏镇江  HTTP  297天  17-11-03 13:34
# 76     59.40.51.214   8010  广东深圳市罗湖区  HTTP    2天  17-11-03 13:30
# 77   58.251.235.118   9000      广东深圳  HTTP   8小时  17-11-03 13:27
# 78   110.73.163.178   8123      广西柳州  HTTP   1分钟  17-11-03 13:15
# 79     59.40.68.243   8010  广东深圳市宝安区  HTTP  15小时  17-11-03 13:12
# 80    110.73.10.200   8123     广西防城港  HTTP  528天  17-11-03 12:50
# 81    121.31.85.233   8123      广西梧州  HTTP  12分钟  17-11-03 12:43
# 82    171.38.15.204   8123      广西玉林  HTTP   1分钟  17-11-03 12:31
# 83  111.155.116.217   8123        北京  HTTP  214天  17-11-03 12:16
# 84   111.155.124.73   8123        北京  HTTP  465天  17-11-03 12:16
# 85    222.186.45.59  62386      江苏镇江  HTTP  312天  17-11-03 12:12
# 86     125.81.68.40   8123        重庆  HTTP   1分钟  17-11-03 12:01
# 87     42.84.43.226   8888        辽宁  HTTP  12小时  17-11-03 11:43
# 88    113.228.63.62   8080      辽宁鞍山  HTTP    1天  17-11-03 11:40
# 89    183.129.6.108    808      浙江杭州  HTTP   3分钟  17-11-03 11:33
# 90   119.145.203.58     80      广东深圳  HTTP  484天  17-11-03 11:11
# 91      59.40.51.46   8010  广东深圳市罗湖区  HTTP   17天  17-11-03 11:06
# 92    36.248.207.31   8118      福建福州  HTTP    2天  17-11-03 11:00
# 93   121.31.103.236   8123     广西防城港  HTTP  520天  17-11-03 10:55
# 94     218.56.38.46     80      山东烟台  HTTP   4分钟  17-11-03 10:50
# 95   124.237.128.18   9999      河北保定  HTTP  10分钟  17-11-03 10:40
# 96  111.155.116.212   8123        北京  HTTP  218天  17-11-03 10:40
# 97   61.178.238.122  63000  甘肃兰州市城关区  HTTP  609天  17-11-03 10:37
#
# [98 rows x 6 columns]

# %%
data2.to_csv('data/ip_list.csv',header=False,index=False,mode='a+')

# %%
res=requests.get('http://httpbin.org/',proxies={'ip':'http//14.211.35.140'},timeout=5)
res.status_code
# Out:
# 200

# %%
real_ip=[]
for data in data1:
    proxy={'ip':'http//{}'.format(data[0])}
    #print(proxy)
    res=requests.get('http://httpbin.org/',proxies=proxy,timeout=5)
    if res.status_code==200:
        print("该ip地址有效：{}".format(data[0]))
        real_ip.append(data[0])
print(real_ip,len(real_ip))
# Out:
# 该ip地址有效：111.155.116.225
# 该ip地址有效：110.73.8.218
# 该ip地址有效：120.32.208.204
# 该ip地址有效：101.87.85.184
# 该ip地址有效：182.34.48.145
# 该ip地址有效：211.103.208.244
# 该ip地址有效：58.255.45.228
# 该ip地址有效：180.168.179.193
# 该ip地址有效：118.178.124.33
# 该ip地址有效：61.135.217.7
# 该ip地址有效：27.46.41.141
# 该ip地址有效：59.78.37.159
# 该ip地址有效：124.93.84.175
# 该ip地址有效：113.123.48.73
# 该ip地址有效：221.204.11.8
# 该ip地址有效：27.44.162.242
# 该ip地址有效：39.69.15.245
# 该ip地址有效：117.68.193.87
# 该ip地址有效：101.68.73.54
# 该ip地址有效：171.217.2.95
# 该ip地址有效：121.35.243.157
# 该ip地址有效：27.219.37.185
# 该ip地址有效：182.88.129.43
# 该ip地址有效：111.155.116.200
# 该ip地址有效：61.155.164.110
# 该ip地址有效：110.73.3.149
# 该ip地址有效：111.155.116.215
# 该ip地址有效：111.155.116.208
# 该ip地址有效：117.78.37.198
# 该ip地址有效：116.6.228.51
# 该ip地址有效：175.164.30.185
# 该ip地址有效：218.18.232.29
# 该ip地址有效：61.155.164.108
# 该ip地址有效：180.173.152.82
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# G:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\response.py in _error_catcher(self)
#     301             try:
# --> 302                 yield
#     303
#
# G:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#
# G:\ProgramData\Anaconda3\lib\http\client.py in read(self, amt)
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#
# G:\ProgramData\Anaconda3\lib\http\client.py in readinto(self, b)
#     492         # (for example, reading in 1k chunks)
# --> 493         n = self.fp.readinto(b)
#     494         if not n and b:
#
# G:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# G:\ProgramData\Anaconda3\lib\site-packages\requests\models.py in generate()
#     737                 try:
# --> 738                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     739                         yield chunk
#
# G:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\response.py in stream(self, amt, decode_content)
#     435             while not is_fp_closed(self._fp):
# --> 436                 data = self.read(amt=amt, decode_content=decode_content)
#     437
#
# G:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     400                         # Content-Length are caught.
# --> 401                         raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#     402
#
# G:\ProgramData\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#      99             try:
# --> 100                 self.gen.throw(type, value, traceback)
#     101                 raise RuntimeError("generator didn't stop after throw()")
#
# G:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\response.py in _error_catcher(self)
#     306                 # there is yet no clean way to get at it from this context.
# --> 307                 raise ReadTimeoutError(self._pool, None, 'Read timed out.')
#     308
#
# ReadTimeoutError: HTTPConnectionPool(host='httpbin.org', port=80): Read timed out.
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-11-610d2ca85d8e> in <module>()
#       3     proxy={'ip':'http//{}'.format(data[0])}
#       4     #print(proxy)
# ----> 5     res=requests.get('http://httpbin.org/',proxies=proxy,timeout=5)
#       6     if res.status_code==200:
#       7         print("该ip地址有效：{}".format(data[0]))
#
# G:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# G:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# G:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         }
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#     520         return resp
#
# G:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     670
#     671         if not stream:
# --> 672             r.content
#     673
#     674         return r
#
# G:\ProgramData\Anaconda3\lib\site-packages\requests\models.py in content(self)
#     814                 self._content = None
#     815             else:
# --> 816                 self._content = bytes().join(self.iter_content(CONTENT_CHUNK_SIZE)) or bytes()
#     817
#     818         self._content_consumed = True
#
# G:\ProgramData\Anaconda3\lib\site-packages\requests\models.py in generate()
#     743                     raise ContentDecodingError(e)
#     744                 except ReadTimeoutError as e:
# --> 745                     raise ConnectionError(e)
#     746             else:
#     747                 # Standard file-like object.
#
# ConnectionError: HTTPConnectionPool(host='httpbin.org', port=80): Read timed out.
